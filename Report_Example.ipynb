# %% [markdown]
# <a href="https://colab.research.google.com/github/KingKouame/KingKouame/blob/main/Report_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For this task, I have decided to use Google Colab as it is easier to use for me and I am more familiar with the platform.
#
# To get started, first we are importing 'pandas' which will allow us to select data from a dataset.

# %%
import pandas as pd

# %% [markdown]
# I mount my Google drive which will give me access to the files I upload.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# To ensure I have the correct file and access to the document, I run the first 5 lines.

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/balance.txt', sep=' ')
df.head(5)
# Out:
#      Balance   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0  12.240798   14.891   3606     283      2   34         11    Male      No
# 1  23.283334  106.025   6645     483      3   82         15  Female     Yes
# 2  22.530409  104.593   7075     514      4   71         11    Male      No
# 3  27.652811  148.924   9504     681      3   36         11  Female      No
# 4  16.893978   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity
# 0     Yes  Caucasian
# 1     Yes      Asian
# 2      No      Asian
# 3      No      Asian
# 4     Yes  Caucasian

# %%
# prompt: Using dataframe df: Compare the average income based on ethnicity

df.groupby('Ethnicity')['Income'].mean()

# %%
df.groupby('Ethnicity')['Income'].mean()
# Out:
# Ethnicity
# African American    47.682101
# Asian               44.187833
# Caucasian           44.521945
# Name: Income, dtype: float64

# %%
# prompt: sort the observations by 'Education', with the users with a high education value first.

df.sort_values(by='Education', ascending=False)

# %%
# I will then select the 'Limit' and 'Rating' columns in the first five observations.

df[['Limit', 'Rating']].head(5)
# Out:
#    Limit  Rating
# 0   3606     283
# 1   6645     483
# 2   7075     514
# 3   9504     681
# 4   4897     357

# %%
# Then I will select the first five observations having 4 cards.

df[df['Cards'] == 4].head(5)
# Out:
#       Balance   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 2   22.530409  104.593   7075     514      4   71         11    Male      No
# 5   22.486178   80.180   8047     569      4   77         10    Male      No
# 10  13.994990   63.095   8117     589      4   30         14    Male      No
# 20   9.853100   17.700   2860     235      4   63         16  Female      No
# 29  14.007770   26.813   5611     411      4   55         16  Female      No
#
#    Married  Ethnicity
# 2       No      Asian
# 5       No  Caucasian
# 10     Yes  Caucasian
# 20      No      Asian
# 29      No  Caucasian

# %%
# We then rank the observations using the 'Education' column from the highest number to the lowest, with the highest education number ranked first and so on.

df.sort_values(by='Education', ascending=False)
# Out:
#        Balance   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 60   13.297283   35.510   5198     364      2   35         20  Female      No
# 51   13.010768   39.705   3969     301      2   27         20    Male      No
# 378  10.140785   19.349   4941     366      1   33         19    Male      No
# 247  13.774598   36.364   2220     188      3   50         19    Male      No
# 238  11.079748   26.532   2910     236      6   58         19  Female      No
# ..         ...      ...    ...     ...    ...  ...        ...     ...     ...
# 284   8.298482   14.711   2047     167      2   67          6    Male      No
# 368  19.555838   89.000   5759     440      3   37          6  Female      No
# 224  25.262836  121.709   7818     584      4   50          6    Male      No
# 254  13.997826   36.508   6386     469      4   79          6  Female      No
# 30   10.201523   34.142   5666     413      4   47          5  Female      No
#
#     Married         Ethnicity
# ...

# %%
# Here we are getting all the ranges in the observations.

df.iloc[:,:]
# Out:
#        Balance   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0    12.240798   14.891   3606     283      2   34         11    Male      No
# 1    23.283334  106.025   6645     483      3   82         15  Female     Yes
# 2    22.530409  104.593   7075     514      4   71         11    Male      No
# 3    27.652811  148.924   9504     681      3   36         11  Female      No
# 4    16.893978   55.882   4897     357      2   68         16    Male      No
# ..         ...      ...    ...     ...    ...  ...        ...     ...     ...
# 395   8.764984   12.096   4100     307      3   32         13    Male      No
# 396   9.943838   13.364   3838     296      5   65         17    Male      No
# 397  14.882078   57.872   4171     321      5   67         12  Female      No
# 398  12.001071   37.728   2525     192      1   44         13    Male      No
# 399  10.159598   18.701   5524     415      5   64          7  Female      No
#
#     Married         Ethnicity
# ...

# %%
# This function below allows us to start looking at the range by locating the next line of index after the first four index. Then we only focus on the five columns starting from the 'Age' column for that range.

df.iloc[5:, 5:]
# Out:
#      Age  Education  Gender Student Married         Ethnicity
# 5     77         10    Male      No      No         Caucasian
# 6     37         12  Female      No      No  African American
# 7     87          9    Male      No      No             Asian
# 8     66         13  Female      No      No         Caucasian
# 9     41         19  Female     Yes     Yes  African American
# ..   ...        ...     ...     ...     ...               ...
# 395   32         13    Male      No     Yes         Caucasian
# 396   65         17    Male      No      No  African American
# 397   67         12  Female      No     Yes         Caucasian
# 398   44         13    Male      No     Yes         Caucasian
# 399   64          7  Female      No      No             Asian
#
# [395 rows x 6 columns]

# %%
# This function allows us to only look at the 'Balance' in the obersations.

df.iloc[:,0]
# Out:
# 0      12.240798
# 1      23.283334
# 2      22.530409
# 3      27.652811
# 4      16.893978
#          ...
# 395     8.764984
# 396     9.943838
# 397    14.882078
# 398    12.001071
# 399    10.159598
# Name: Balance, Length: 400, dtype: float64

# %%
# This function focuses specifically on index label 9 for its values.

df.iloc[9,:]
# Out:
# Balance             17.756965
# Income                 71.061
# Limit                    6819
# Rating                    491
# Cards                       3
# Age                        41
# Education                  19
# Gender                 Female
# Student                   Yes
# Married                   Yes
# Ethnicity    African American
# Name: 9, dtype: object
